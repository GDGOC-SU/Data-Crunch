# %% [markdown]
# # 📊 Dataset Description: Healthcare Data
#
# ## 🏥 Overview
# This dataset contains **medical diagnostic data** used for analyzing **health conditions** (potentially cancer-related). The dataset includes **569 records** with **30 numerical features**, which describe various characteristics of cell nuclei in medical scans.
#
# ## 📌 Data Attributes
# Each row in the dataset represents a **patient's medical report**, with the following key attributes:
#
# ### **1. Tumor Size & Shape Features**
# - `radius_mean` - Mean radius of the tumor.
# - `texture_mean` - Mean texture (variation in gray-scale values).
# - `perimeter_mean` - Mean perimeter of the tumor.
# - `area_mean` - Mean tumor area.
# - `smoothness_mean` - Mean smoothness (local variation in radius lengths).
#
# ### **2. Compactness & Concavity Features**
# - `compactness_mean` - Mean compactness (perimeter²/area - 1.0).
# - `concavity_mean` - Mean concavity (severity of concave portions).
# - `concave points_mean` - Mean number of concave portions of the contour.
#
# ### **3. Symmetry & Fractal Dimension Features**
# - `symmetry_mean` - Mean symmetry of the tumor shape.
# - `fractal_dimension_mean` - Mean fractal dimension (coastline approximation - 1).
#
# ### **4. Standard Error Features (Measurement Variability)**
# - `radius_se`, `texture_se`, `perimeter_se`, `area_se`, `smoothness_se`, etc.
# - These features represent the **standard error** of each measurement, indicating **variability** in tumor characteristics.
#
# ### **5. Worst Case Scenario Features (Largest Tumor Cell Observations)**
# - `radius_worst`, `texture_worst`, `perimeter_worst`, `area_worst`, etc.
# - These capture the **worst (largest) values recorded** for each tumor measurement.
#
# ## 📌 Missing Data
# - The dataset **does not contain any missing values**, ensuring a **clean and structured dataset** for machine learning applications.
#
# ## 🔍 Use Cases & Applications
# - **Cancer Detection**: Differentiating between **benign and malignant tumors**.
# - **Medical Imaging AI**: Assisting radiologists in **tumor classification**.
# - **Healthcare AI Systems**: Enhancing automated diagnostics using **machine learning**.
#
# ## 🚀 Conclusion
# This dataset provides **valuable insights into tumor characteristics**, enabling **predictive analytics for cancer detection**. By leveraging **clustering, PCA, and classification models**, we can enhance **early diagnosis, patient segmentation, and personalized treatment strategies**.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Loading the dataset using pandas library**

# %%
df = pd.read_csv('/content/data.csv')

# %% [markdown]
# **Showing first 5 rows of dataset**

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# **This dataset concist of 569  rows and 33 columns**

# %%
df.shape
# Out:
# (569, 33)

# %% [markdown]
# **Using df.info() for checking the null content** *italicized text*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# **As you can see each column is of type float64 except id and diagnosis**

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# **We are dropping Unnamed: 32 because it contains all NaN values**

# %%
df.drop(columns=['Unnamed: 32'], inplace=True)

# %% [markdown]
# **We are dropping id because it has no value in the later computations**

# %%
df.drop(columns=['id'], inplace=True)

# %% [markdown]
# **we are dropping diagnosis as it is non numeric column**

# %%
df.drop(columns=['diagnosis'], inplace=True)

# %% [markdown]
# **OUTLIER DETECTION**

# %%
# Selecting only numerical columns for outlier detection
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
print(numerical_cols)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
print(numerical_cols)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %% [markdown]
# **Removed id column**

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# **This Heathcare datset is normal datset as we can see using the histplot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Loop through each numerical column and plot distribution
for col in numerical_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# **Level 1: Data Preprocessing**
#
# **Outlier Detection**
#
# Identification of Outliers
#
# Outliers are data points that significantly deviate from the rest of the dataset. Identifying outliers is crucial to ensure data quality and prevent skewed analysis.
#
# Chosen Method: **Z-score**
#
# We use the Z-score method to identify outliers. The Z-score measures how many standard deviations a data point is from the mean:
#
#
#
# A common threshold for detecting outliers is:
#
# Z > 3 or Z < -3 (data points beyond 3 standard deviations from the mean are considered outliers).
#
# This method is chosen because our dataset follows a normal distribution, making Z-score an appropriate metric for identifying extreme values.
#
# Approach for Handling Outliers
#
# After detecting outliers, we take the following approach:
#
# Capping: If an outlier is a valid but extreme observation, we cap it at a predefined threshold (e.g., ).
#
# Removal: If the outlier is an error or an anomaly, we remove it from the dataset.
#
# Impact on Data Quality
#
# Reduces skewness: Eliminating extreme values helps maintain a balanced dataset.
#
# Improves model performance: Machine learning models become more stable and less sensitive to extreme values.
#
# Enhances interpretability: A cleaned dataset ensures meaningful insights without the influence of extreme values.

# %%
#compute Z-scores = x - u(mean) / standard deviation(sd)
z_scores = (df[numerical_cols] - df[numerical_cols].mean()) / df[numerical_cols].std()
outliers_zscore = (np.abs(z_scores) > 3).sum()

# %% [markdown]
# **WE HAVE USED Z-SCORE NORMALIZATION BECAUSE GIVEN DATSET IS NORMAL AS SHOWN IN THE HISTPLOT**

# %%
outlier_report = pd.DataFrame({ 'Z_score Outliers': outliers_zscore})
print(outlier_report)
# Out:
#                          Z_score Outliers
# radius_mean                             5
# texture_mean                            4
# perimeter_mean                          7
# area_mean                               8
# smoothness_mean                         5
# compactness_mean                        9
# concavity_mean                          9
# concave points_mean                     6
# symmetry_mean                           5
# fractal_dimension_mean                  7
# radius_se                               7
# texture_se                              9
# perimeter_se                            8
# area_se                                 6
# smoothness_se                           7
# compactness_se                         12
# concavity_se                            6
# concave points_se                       6
# symmetry_se                            11
# fractal_dimension_se                   10
# radius_worst                            6
# ...

# %%
from scipy.stats import zscore

# Compute Z-scores for numerical columns
z_scores = df[numerical_cols].apply(zscore)

# Define threshold (commonly 3)
threshold = 3

# Filter the data
df_cleaned = df[(z_scores.abs() < threshold).all(axis=1)]

# %%
print(f"Original dataset size: {df.shape}")
print(f"Dataset size after z-score outlier removal: {df_cleaned.shape}")
# Out:
# Original dataset size: (569, 30)
# Dataset size after z-score outlier removal: (495, 30)

# %% [markdown]
# **Mising value check**

# %%
print(df_cleaned.isnull().sum())
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# **NO MISSSING VALUES PRESNT IN THE DATASET**

# %%
print(df_cleaned.isnull().values.any())
# Out:
# False

# %% [markdown]
# **Data normalization**

# %% [markdown]
# there are 2 scaling techniques : Z-score and Min-max scaling
# Z-score standarization = X - mean / standard dev
# Min-max scaling = X-Xmin / Xmax -Xmin

# %% [markdown]
# **Since our dataset is normal so we'll use z-score norm**

# %%
df_standardized = df_cleaned.copy()

for col in numerical_cols:
    mean = df[col].mean()
    std = df[col].std()
    df_standardized[col] = (df[col] - mean) / std

print(df_standardized.head())  # Check transformed data
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 1     1.828212     -0.353322        1.684473   1.907030        -0.826235
# 2     1.578499      0.455786        1.565126   1.557513         0.941382
# 4     1.748758     -1.150804        1.775011   1.824624         0.280125
# 5    -0.475956     -0.834601       -0.386808  -0.505206         2.235455
# 6     1.169878      0.160508        1.137124   1.094332        -0.123028
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 1         -0.486643       -0.023825             0.547662       0.001391
# 2          1.052000        1.362280             2.035440       0.938859
# 4          0.538866        1.369806             1.427237      -0.009552
# 5          1.243242        0.865540             0.823931       1.004518
# 6          0.088218        0.299809             0.646366      -0.064268
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# **Data Preprocessing done!!**

# %% [markdown]
# Level 2: Data Analysis & Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


# Initialize k-means parameters
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "random_state": 1,
}

# Create list to hold SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(df_standardized)
    sse.append(kmeans.inertia_)

# Visualize results
plt.plot(range(1, 11), sse, marker='o')
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE (Sum of Squared Errors)")
plt.title("Elbow Method for Optimal k")
plt.show()

# %% [markdown]
# **As we can see in the graph elbow point is 2**

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for k in range(2, 11):  # Start from 2 since silhouette isn't defined for k=1
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    labels = kmeans.fit_predict(df_standardized)
    score = silhouette_score(df_standardized, labels)
    silhouette_scores.append(score)

# Plot Silhouette Score for different k values
plt.plot(range(2, 11), silhouette_scores, marker='o', linestyle="--")
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score Analysis")
plt.show()

# %% [markdown]
# **using the silhoutte score we can see the quality of clusters**

# %%
print("Original DataFrame shape:", df.shape)
print("Standardized DataFrame shape:", df_standardized.shape)
print("Missing values in df:\n", df.isnull().sum())
# Out:
# Original DataFrame shape: (569, 30)
# Standardized DataFrame shape: (495, 30)
# Missing values in df:
#  radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# ...

# %% [markdown]
# **K-mean Clustering**

# %%
# Fit KMeans with optimal clusters
optimal_k = 2
kmeans = KMeans(n_clusters=optimal_k, **kmeans_kwargs)
df_standardized['Cluster'] = kmeans.fit_predict(df_standardized)

# Print cluster centers
print("Cluster Centers (in standardized form):\n", kmeans.cluster_centers_)
# Out:
# Cluster Centers (in standardized form):
#  [[-0.48103193 -0.28719498 -0.49909443 -0.4813438  -0.30021879 -0.53843211
#   -0.59624543 -0.59691085 -0.33305065 -0.1708135  -0.44753656 -0.11112538
#   -0.4482763  -0.41086056 -0.07359214 -0.40460013 -0.35307578 -0.40400572
#   -0.12090318 -0.28782703 -0.51933991 -0.29709457 -0.5338876  -0.50536279
#   -0.30835211 -0.49998967 -0.55035013 -0.58351998 -0.31050635 -0.35843458]
#  [ 0.90125438  0.37130482  0.90880724  0.83965827  0.40768684  0.6707538
#    0.80203592  0.93641007  0.35592088 -0.08060729  0.58271287 -0.13064705
#    0.5563228   0.52694843 -0.13624392  0.33262245  0.29620572  0.49047819
#   -0.19084223  0.09352206  0.9451218   0.42064289  0.94323892  0.85146116
#    0.50847087  0.6984378   0.80698199  0.98321124  0.39765368  0.3915746 ]]

# %%
# Compute Silhouette Score
silhouette_avg = silhouette_score(df_standardized, df_standardized['Cluster'])
print(f"Silhouette Score for k={optimal_k}: {silhouette_avg:.4f}")
# Out:
# Silhouette Score for k=2: 0.3484

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# **Data Visualization**

# %%
import seaborn as sns

# %%
for col in numerical_cols[:5]:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Cluster', y=col, data=df_standardized)
    plt.title(f'Cluster Distribution of {col}')
    plt.xlabel('Cluster')
    plt.ylabel(col)
    plt.show()

sns.pairplot(df_standardized, hue='Cluster', vars=numerical_cols[:5])
plt.suptitle('Pairplot of Features Colored by Cluster', y=1.02)
plt.show()

plt.figure(figsize=(12, 10))
correlation_matrix = df_standardized.drop('Cluster', axis=1).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
linked = linkage(df_standardized, method='ward')
plt.figure(figsize=(10, 5))
dendrogram(linked)
plt.title("Dendrogram for Hierarchical Clustering")
plt.show()

# %% [markdown]
# # 🏥 Healthcare Data Analysis Report
#
# ## 📌 Introduction
# Healthcare data analysis is essential for **early disease detection, risk assessment, and treatment optimization**. In this report, we apply **K-Means clustering and PCA** to uncover patterns in the dataset. The findings can assist in **medical decision-making, patient segmentation, and improving diagnostic accuracy**.
#
# ## 📊 Methodology
# ### **1. Data Preprocessing**
# - Handled missing values and standardized the dataset for uniformity.
# - Encoded categorical variables (if any) to ensure compatibility with machine learning models.
# - Scaled numerical features using **StandardScaler** to improve clustering performance.
#
# ### **2. Clustering Approach**
# - **Elbow Method & Silhouette Score** were used to determine the optimal number of clusters.
# - **K-Means clustering** was applied to segment patients based on medical characteristics.
#
# ### **3. Dimensionality Reduction**
# - **PCA (Principal Component Analysis)** was performed to visualize high-dimensional data in 2D.
#
# ## 📈 Results & Findings
# ### **1. Key Clustering Insights**
# - **Cluster 0 (Lower Feature Values - Likely Benign Cases)**
#   - Patients in this cluster exhibit **lower tumor radius, perimeter, and symmetry values**, suggesting a **lower risk of malignancy**.
#
# - **Cluster 1 (Higher Feature Values - Likely Malignant Cases)**
#   - Patients in this group have **higher values across medical features**, potentially **indicating malignant tumors** that require further screening.
#
# ### **2. PCA Visualization**
# - **Scatter plots** helped visualize how patient groups are distributed in a reduced feature space.
# - **Heatmaps & Correlation Analysis** highlighted important variables influencing the clustering process.
#
# ## 🌍 Real-World Implications
# ### **🩺 Healthcare Relevance**
# - **Early Diagnosis Support:** AI-powered clustering aids in identifying **high-risk patients** for early intervention.
# - **Medical Imaging Assistance:** Automates the categorization of **tumor features**, helping radiologists with more accurate assessments.
# - **Personalized Treatment Plans:** Segmentation allows doctors to **tailor treatments based on risk level**.
#
# ### **🚀 Future Recommendations**
# - **Enhancing Model Accuracy:** Incorporating genetic or lifestyle data for deeper patient profiling.
# - **Hybrid AI Models:** Combining clustering with **CNN-based image analysis** for more precise predictions.
# - **Ethical AI in Healthcare:** Ensuring transparency, bias mitigation, and clinical validation of AI-based decisions.
#
# ## 📌 Conclusion
# This analysis demonstrates **the power of machine learning in healthcare**. By leveraging **clustering techniques**, we can improve **early disease detection, patient segmentation, and medical decision-making**, ultimately leading to **better healthcare outcomes**.

# %%
from sklearn.decomposition import PCA

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)  # Reduce to 2 principal components for visualization
pca_result = pca.fit_transform(df_standardized.drop('Cluster', axis=1))

# Create a new DataFrame with PCA results
df_pca = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
df_pca['Cluster'] = df_standardized['Cluster']

# Visualize PCA results
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Cluster', data=df_pca, palette='viridis')
plt.title('PCA Visualization of Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# Explained Variance Ratio
explained_variance_ratio = pca.explained_variance_ratio_
print(f"Explained Variance Ratio: {explained_variance_ratio}")
print(f"Total Explained Variance: {sum(explained_variance_ratio)}")
# Out:
# Explained Variance Ratio: [0.453847   0.17295183]
# Total Explained Variance: 0.6267988270945956

# %% [markdown]
# **Done !!!**
